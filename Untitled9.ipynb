# %% [markdown]
# <a href="https://colab.research.google.com/github/alexiseduardodiazdeleonhernand-bit/alex/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data_frame = pd.read_csv("datos_casas_india.csv")

# %% [markdown]
# obtener  toda la informacion de dataframe

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   house_type        5000 non-null   object
#  1   house_size        5000 non-null   object
#  2   location          5000 non-null   object
#  3   city              5000 non-null   object
#  4   latitude          5000 non-null   float64
#  5   longitude         5000 non-null   float64
#  6   price             5000 non-null   int64
#  7   currency          5000 non-null   object
#  8   numBathrooms      4975 non-null   float64
#  9   numBalconies      2737 non-null   float64
#  10  isNegotiable      179 non-null    object
#  11  priceSqFt         0 non-null      float64
#  12  verificationDate  5000 non-null   object
#  13  description       4715 non-null   object
#  14  SecurityDeposit   5000 non-null   object
#  15  Status            5000 non-null   object
# ...

# %% [markdown]
# máscara para filtrar por precio >= 10,000

# %%
print(data_frame[data_frame["price"] >= 10000])
# Out:
#                     house_type   house_size            location   city  \
# 0       1 RK Studio Apartment     400 sq ft             Kalkaji  Delhi
# 1       1 RK Studio Apartment     400 sq ft   Mansarover Garden  Delhi
# 3     3 BHK Independent House   1,020 sq ft          Model Town  Delhi
# 4             2 BHK Apartment     810 sq ft    Sector 13 Rohini  Delhi
# 5             3 BHK Apartment     750 sq ft           DLF Farms  Delhi
# ...                        ...          ...                 ...    ...
# 4995              4 BHK Villa   5,896 sq ft        Sunder Nagar  Delhi
# 4996  5 BHK Independent House   6,521 sq ft        Sunder Nagar  Delhi
# 4997  3 BHK Independent Floor   1,855 sq ft  New Friends Colony  Delhi
# 4998  3 BHK Independent Floor   2,856 sq ft  New Friends Colony  Delhi
# 4999  3 BHK Independent Floor   2,856 sq ft  New Friends Colony  Delhi
#
#        latitude  longitude    price currency  numBathrooms  numBalconies  \
# ...

# %% [markdown]
# cuantas son inferiores a 10,000

# %%
print(data_frame[data_frame["price"] < 10000])
# Out:
#                     house_type   house_size        location   city   latitude  \
# 2     2 BHK Independent Floor     500 sq ft     Uttam Nagar  Delhi  28.618677
# 77    1 BHK Independent Floor     700 sq ft     Uttam Nagar  Delhi  28.619457
# 84    1 BHK Independent Floor     360 sq ft        Badarpur  Delhi  28.491892
# 88            2 BHK Apartment     480 sq ft     Uttam Nagar  Delhi  28.618303
# 93    1 BHK Independent Floor     450 sq ft  Mansa Ram Park  Delhi  28.618078
# ...                        ...          ...             ...    ...        ...
# 4499  2 BHK Independent House     445 sq ft          Burari  Delhi  28.760500
# 4502          2 BHK Apartment   1,800 sq ft     Uttam Nagar  Delhi  28.618809
# 4503  1 BHK Independent Floor     500 sq ft           Saket  Delhi  28.523548
# 4939  1 BHK Independent House     333 sq ft        dda flat  Delhi  28.655981
# 4948          1 BHK Apartment     450 sq ft          Nawada  Delhi  28.627590
#
# ...

# %% [markdown]
# dataframe con los valores de casas inferiores a 10,000

# %%
df = data_frame['price'] < 10000
df
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Name: price, Length: 5000, dtype: bool

# %% [markdown]
# toda la info del df

# %%
df.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5000 entries, 0 to 4999
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 5000 non-null   bool
# dtypes: bool(1)
# memory usage: 5.0 KB

# %% [markdown]
# crear una serie con todas las direcciones de las casas >= 10,000

# %%
s = data_frame[data_frame["price"] >= 10000]["location"]
s
# Out:
# 0                  Kalkaji
# 1        Mansarover Garden
# 3               Model Town
# 4         Sector 13 Rohini
# 5                DLF Farms
#                ...
# 4995          Sunder Nagar
# 4996          Sunder Nagar
# 4997    New Friends Colony
# 4998    New Friends Colony
# 4999    New Friends Colony
# Name: location, Length: 4827, dtype: object
